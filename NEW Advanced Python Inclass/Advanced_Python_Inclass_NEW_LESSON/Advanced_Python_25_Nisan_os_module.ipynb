# %% [markdown]
# # OS (Operating System) MODULE

# %% [raw]
# Kod yazarkenn öncelikle   araştır başka biri yazıp  paylaşmış olabiri
# python package e bak
# paythonda    dosya  oluşturmak  için bir yol vereceğiz
# web tabanlı  bir   çaloışmada  karşıdan dosya isteyeceğiz   bunu için bir yol vermeliyiz
# csv  ve txt  dosyalarında  de  üzerine  yazma yapılabiliyor overright yapılabiliyor
#
# current  working  directory cwd,
# path  yol

# %%
#çalışma  süresini  verir %%time  
# !pip install django
# Out:
# ...
#      ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/8.0 MB 1.4 MB/s eta 0:00:06
#      ---------------------------------------- 0.0/8.0 MB 393.8 kB/s eta 0:00:21
#      ---------------------------------------- 0.1/8.0 MB 751.6 kB/s eta 0:00:11
#       --------------------------------------- 0.1/8.0 MB 711.9 kB/s eta 0:00:12
#      - -------------------------------------- 0.2/8.0 MB 1.1 MB/s eta 0:00:08
#      - -------------------------------------- 0.3/8.0 MB 1.1 MB/s eta 0:00:08
#      -- ------------------------------------- 0.5/8.0 MB 1.6 MB/s eta 0:00:05
#      -- ------------------------------------- 0.5/8.0 MB 1.4 MB/s eta 0:00:06
#      --- ------------------------------------ 0.8/8.0 MB 1.9 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.0/8.0 MB 2.2 MB/s eta 0:00:04
#      ------ --------------------------------- 1.2/8.0 MB 2.3 MB/s eta 0:00:03
# ...

# %% [raw]
# ## ubuntu  da   /  bu  windosta \\ böyle

# %% [raw]
# #  r"c:\\" # "c://" mac ile  ubuntu  terminali aynı
# dosyaya  pet   yani yol vermelyiz  windows \\ kabul etmiyor

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## OS

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\Administrator\OneDrive\Masaüstü\Python Lessons

# %%
# os klasör   dizin değiştirme
os.chdir("dizin-os")

# %%
print(os.getcwd())
# Out:
# C:\Users\Administrator\OneDrive\Masaüstü\Python Lessons\dizin-os

# %%
os.chdir(r"C:\Users\Administrator\OneDrive\Masaüstü\Python Lessons\dizin-os")
print(os.getcwd())
# Out:
# C:\Users\Administrator\OneDrive\Masaüstü\Python Lessons\dizin-os

# %%
# %cd "dizin-os" # magic comment genel  kültür
# Out:
# [WinError 2] The system cannot find the file specified: 'dizin-os'
# C:\Users\Administrator\OneDrive\Masaüstü\Python Lessons

# %%
# %cd.. ubuntu da  geri gider
# Out:
# UsageError: Line magic function `%cd..` not found.

# %%
dosya_listesi = os.listdir() # içindeki  dosyaları   listeler

# %%
dosya_listesi
# Out:
# []

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for i in os.walk():
    print("Klasör yolu: ", i[0]) # 1. index kalsörleri
    print("Klasörler : ", i[1])# 2. index klas
    print("dosyalar: ", i[2]) # 3. index dosyaları   basar
